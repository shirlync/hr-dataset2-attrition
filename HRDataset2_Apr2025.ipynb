# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly import __version__ as pvm

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv ('C:\\Users\\shirl\\OneDrive\\Desktop\\HRDataset2_Attrition_160425.csv')

# %%
df.head()
# Out:
#    EmployeeNumber  Attrition AgeGroup                JobRole  DailyRate  \
# 0               1          1    36-45        Sales Executive       1102
# 1               2          0    46-55     Research Scientist        279
# 2               4          1    36-45  Laboratory Technician       1373
# 3               5          0    26-35     Research Scientist       1392
# 4               7          0    26-35  Laboratory Technician        591
#
#    HourlyRate  MonthlyIncome              Department     BusinessTravel  \
# 0          94           5993                   Sales      Travel_Rarely
# 1          61           5130  Research & Development  Travel_Frequently
# 2          92           2090  Research & Development      Travel_Rarely
# 3          56           2909  Research & Development  Travel_Frequently
# 4          40           3468  Research & Development      Travel_Rarely
#
#    EnvironmentSatisfaction  JobSatisfaction  OverTime  PerformanceRating  \
# ...

# %%
print('Missing Value Counts for Each Column\n' + '='*36)

print(df.isnull().sum())
# Out:
# Missing Value Counts for Each Column
# ...
# EmployeeNumber               0
# Attrition                    0
# AgeGroup                     0
# JobRole                      0
# DailyRate                    0
# HourlyRate                   0
# MonthlyIncome                0
# Department                   0
# BusinessTravel               0
# EnvironmentSatisfaction      0
# JobSatisfaction              0
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager        57
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1480 entries, 0 to 1479
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            1480 non-null   int64
#  1   Attrition                 1480 non-null   int64
#  2   AgeGroup                  1480 non-null   object
#  3   JobRole                   1480 non-null   object
#  4   DailyRate                 1480 non-null   int64
#  5   HourlyRate                1480 non-null   int64
#  6   MonthlyIncome             1480 non-null   int64
#  7   Department                1480 non-null   object
#  8   BusinessTravel            1480 non-null   object
#  9   EnvironmentSatisfaction   1480 non-null   int64
#  10  JobSatisfaction           1480 non-null   int64
#  11  OverTime                  1480 non-null   int64
#  12  PerformanceRating         1480 non-null   int64
#  13  RelationshipSatisfaction  1480 non-null   int64
# ...

# %%
print('Number of duplicates :', df.duplicated().sum())
# Out:
# Number of duplicates : 7

# %%
df = df.drop_duplicates()

# %%
print('Number of duplicates :', df.duplicated().sum())
# Out:
# Number of duplicates : 0

# %%
df.describe()
# Out:
#        EmployeeNumber    Attrition    DailyRate   HourlyRate  MonthlyIncome  \
# count     1473.000000  1473.000000  1473.000000  1473.000000    1473.000000
# mean      1026.975560     0.160896   802.659878    65.833673    6500.228785
# std        603.223162     0.367560   403.245460    20.350032    4706.053923
# min          1.000000     0.000000   102.000000    30.000000    1009.000000
# 25%        492.000000     0.000000   465.000000    48.000000    2911.000000
# 50%       1024.000000     0.000000   802.000000    66.000000    4908.000000
# 75%       1558.000000     0.000000  1157.000000    83.000000    8380.000000
# max       2068.000000     1.000000  1499.000000   100.000000   19999.000000
#
#        EnvironmentSatisfaction  JobSatisfaction     OverTime  \
# count              1473.000000      1473.000000  1473.000000
# mean                  2.723693         2.728445     0.282417
# std                   1.093006         1.103163     0.450328
# ...

# %%
plt.rcParams['figure.figsize'] = (15, 10)
plt.rcParams.update({'font.size': 13})

# Seaborn styling
sb.set(font_scale=1.5)
sb.set_style(style='white')

# Select only the desired columns
selected_cols = ['EmployeeNumber', 'Attrition', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsSinceLastPromotion', 'EnvironmentSatisfaction', 'JobSatisfaction', 'MonthlyIncome', 'PerformanceRating', 'RelationshipSatisfaction', 'YearsAtCompany']

# Plot heatmap
sb.heatmap(df[selected_cols].corr(), annot=True, linewidth=1, cmap='coolwarm')\
  .set_title('Annotated Correlation Matrix of Selected Columns')
# Out:
# Text(0.5, 1.0, 'Annotated Correlation Matrix of Selected Columns')
